# %% [markdown]
# ## Apriori Frequent Pattern Mining improved using Sampling

# %%
# Importing required libraries
import pandas as pd
import numpy as np
from itertools import combinations
import time

# %%
# Reading data file
adult = pd.read_excel('adult.xlsx')
adult.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Edunum              Marital  \
# 0   39          State-gov   77516   Bachelors      13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors      13   Married-civ-spouse
# 2   38            Private  215646     HS-grad       9             Divorced
# 3   53            Private  234721        11th       7   Married-civ-spouse
# 4   28            Private  338409   Bachelors      13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Gain  Loss  \
# 0        Adm-clerical   Not-in-family   White     Male  2174     0
# 1     Exec-managerial         Husband   White     Male     0     0
# 2   Handlers-cleaners   Not-in-family   White     Male     0     0
# 3   Handlers-cleaners         Husband   Black     Male     0     0
# 4      Prof-specialty            Wife   Black   Female     0     0
#
#    Hoursperweek         Country  Income
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K
# 2            40   United-States   <=50K
# 3            40   United-States   <=50K
# 4            40            Cuba   <=50K

# %%
# Removing irrelevant columns
adult.drop(['fnlwgt', 'Edunum'], axis = 1, inplace = True)
adult.head()
# Out:
#    Age          Workclass   Education              Marital  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Gain  Loss  \
# 0        Adm-clerical   Not-in-family   White     Male  2174     0
# 1     Exec-managerial         Husband   White     Male     0     0
# 2   Handlers-cleaners   Not-in-family   White     Male     0     0
# 3   Handlers-cleaners         Husband   Black     Male     0     0
# 4      Prof-specialty            Wife   Black   Female     0     0
#
#    Hoursperweek         Country  Income
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K
# 2            40   United-States   <=50K
# 3            40   United-States   <=50K
# 4            40            Cuba   <=50K

# %%
# Size of original data
adult.shape
# Out:
# (32561, 13)

# %%
# Removing missing values from data
adult.replace(' ?', np.NaN, inplace = True)
adult.dropna(axis = 0, inplace = True)

# Size of data after removing missing values
adult.shape
# Out:
# (30162, 13)

# %%
# Converting numeric data to categorical data
adult['Age'] = pd.cut(adult['Age'], [0, 25, 40, np.inf], labels=["young", "middle_aged", "old"])
adult['Gain'] = pd.cut(adult['Gain'], [-1, 1, np.inf], labels=["No_Gain", "Gain"])
adult['Loss'] = pd.cut(adult['Loss'], [-1, 1, np.inf], labels=["No_Loss", "Loss"])
adult['Hoursperweek'] = pd.cut(adult['Hoursperweek'], [-1, 5, 20, 60, np.inf], labels=["Less", "Medium", "Reasonable", "High"])
adult.head()
# Out:
#            Age          Workclass   Education              Marital  \
# 0  middle_aged          State-gov   Bachelors        Never-married
# 1          old   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2  middle_aged            Private     HS-grad             Divorced
# 3          old            Private        11th   Married-civ-spouse
# 4  middle_aged            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex     Gain     Loss  \
# 0        Adm-clerical   Not-in-family   White     Male     Gain  No_Loss
# 1     Exec-managerial         Husband   White     Male  No_Gain  No_Loss
# 2   Handlers-cleaners   Not-in-family   White     Male  No_Gain  No_Loss
# 3   Handlers-cleaners         Husband   Black     Male  No_Gain  No_Loss
# 4      Prof-specialty            Wife   Black   Female  No_Gain  No_Loss
#
#   Hoursperweek         Country  Income
# 0   Reasonable   United-States   <=50K
# 1       Medium   United-States   <=50K
# 2   Reasonable   United-States   <=50K
# 3   Reasonable   United-States   <=50K
# 4   Reasonable            Cuba   <=50K

# %%
# Generate a sampled dataset from the input data
def sampling(df, samplingFactor):
    sampledData = df.sample(frac = samplingFactor)
    return sampledData

# %%
# Generating Candidate 1
def C1(data):
    candidates = {} # empty dictionary to store each item as key and its count as value
    for i in data.index:
        for j in data.loc[i]:
            if (j in candidates): 
                candidates[j] += 1
            else: 
                candidates[j] = 1
    print("\nC1: \n", candidates)
    return candidates

# %%
# Generating L1
def L1(c, support):
    l1 = {} # dictionary to store all the items having support more than or equal to minimum support
    l1 = dict((k,v) for k, v in c.items() if v >= support)
    print("\n\nL1: \n", l1)
    return l1

# %%
# Function to check if candidate itemset contains infrequent subset
def has_infrequent_subset(candidate, freq, prevL):
    for i in list(combinations(candidate,freq-1)):
        if i not in prevL:
            return True
        return False

# %%
# Generating Candidate k
def Ck(k, prevL, df):
    
    # Join
    # For C2:
    if k == 2:
        c = list()
        for key,v in prevL.items():
            if key not in c:
                c.append(key)
            
    # When k is greater than 2, L (k-1) contains list of tuples
    if k > 2:
        c = list()
        for key,v in prevL.items():
            for item in key:
                if item not in c:
                    c.append(item)
                    
    candidates = {} # To store all the candidate items along with its count
    cand = list(combinations(c, k))
    
    # Prune
    for cd in cand:
        if (has_infrequent_subset(cd, k, prevL) == True):
            cand.remove(cd)
            
    for i in cand:
        candidates[i] = 0
    for ind in df.index:
        for i in candidates:
            if set(i).issubset(df.loc[ind]):
                candidates[i] +=1
                
    print("\n\nC", k, ":\n", candidates)
    return candidates

# %%
# Generating Lk
def Lk(k, ck, support):
    lk = {}
    # lk contains all the values having support more than minimum support threshold
    lk = dict((key,v) for key, v in ck.items() if v >= support)
    print("\n\nL", k, ":\n", lk)
    return lk

# %%
# Function for Apriori Algorithm
def apriori(data, support, samplingFactor):
    
    s = int((support/100)*0.9*len(data))
    df = sampling(data, samplingFactor)
    t1 = time.time()
    
    print("Minimum support = ", s)
    
    lk = {}
    candidateK = {}
    candidateK = C1(df)
    lk = L1(candidateK, s)
    
    k = 2
    while lk != {}:
        candidateK = Ck(k, lk, data)
        lk = Lk(k, candidateK, s)
        k += 1
    t2 = time.time()
    
    exec_time = t2 - t1
    
    print("\nTotal execution time = ", exec_time)

    return

# %%
apriori(adult, 50, 0.6)
# Out:
# Minimum support =  13572
#
# C1:
#  {'middle_aged': 7244, ' Private': 13355, ' HS-grad': 5919, ' Married-civ-spouse': 8511, ' Exec-managerial': 2361, ' Wife': 852, ' Black': 1704, ' Female': 5816, 'No_Gain': 16585, 'No_Loss': 17212, 'Reasonable': 16030, ' United-States': 16489, ' <=50K': 13625, ' Bachelors': 3007, ' Husband': 7542, ' White': 15520, ' Male': 12281, ' >50K': 4472, ' 11th': 618, ' Craft-repair': 2450, 'Loss': 885, 'old': 7479, ' 9th': 272, ' Adm-clerical': 2176, 'Gain': 1512, ' Transport-moving': 995, ' State-gov': 798, ' Some-college': 4000, ' Protective-serv': 386, ' Local-gov': 1215, 'young': 3374, ' Never-married': 5781, ' Not-in-family': 4613, ' Self-emp-not-inc': 1506, ' Sales': 2109, ' Own-child': 2661, 'Medium': 1363, ' Masters': 973, ' Prof-specialty': 2427, ' Divorced': 2518, ' Other-service': 1959, ' Asian-Pac-Islander': 539, ' Philippines': 109, ' Machine-op-inspct': 1184, ' Unmarried': 1902, 'High': 633, ' Handlers-cleaners': 816, ' Other-relative': 527, ' Self-emp-inc': 654, ' South': 39, ' 10th': 490, ' Separated': 551, ' Prof-school': 340, ' Assoc-voc': 793, ' Mexico': 367, ' Assoc-acdm': 582, ' 12th': 235, ' Federal-gov': 561, ' Laos': 11, ' 1st-4th': 102, ' Cambodia': 11, ' Tech-support': 557, ' Widowed': 505, ' Married-spouse-absent': 219, ' 7th-8th': 340, ' Dominican-Republic': 35, ' 5th-6th': 175, ' Farming-fishing': 581, ' Other': 148, ' Jamaica': 52, ' Haiti': 30, ' Amer-Indian-Eskimo': 186, ' Doctorate': 229, ' Priv-house-serv': 89, ' Cuba': 51, ' Japan': 42, ' Puerto-Rico': 68, ' Nicaragua': 20, ' Greece': 15, ' Peru': 20, ' Germany': 79, ' Ecuador': 12, ' Canada': 68, ' Scotland': 5, ' Vietnam': 46, ' England': 55, ' India': 60, ' El-Salvador': 58, ' Iran': 26, ' China': 39, ' Honduras': 7, ' Trinadad&Tobago': 12, ' Outlying-US(Guam-USVI-etc)': 8, 'Less': 71, ' Hungary': 7, ' Guatemala': 36, ' Taiwan': 28, ' Yugoslavia': 9, ' Poland': 35, ' Italy': 39, ' Thailand': 10, ' Columbia': 34, ' Ireland': 13, ' Preschool': 22, ' France': 22, ' Portugal': 19, ' Married-AF-spouse': 12, ' Hong': 10, ' Armed-Forces': 7, ' Without-pay': 8, ' Holand-Netherlands': 1}
#
#
# L1:
#  {'No_Gain': 16585, 'No_Loss': 17212, 'Reasonable': 16030, ' United-States': 16489, ' <=50K': 13625, ' White': 15520}
#
#
# C 2 :
#  {('No_Gain', 'Reasonable'): 24419, ('No_Gain', ' <=50K'): 21711, ('No_Loss', 'Reasonable'): 25444, ('No_Loss', ' <=50K'): 21964, ('Reasonable', ' United-States'): 24328, ('Reasonable', ' White'): 22922, (' United-States', ' White'): 24218}
#
#
# L 2 :
#  {('No_Gain', 'Reasonable'): 24419, ('No_Gain', ' <=50K'): 21711, ('No_Loss', 'Reasonable'): 25444, ('No_Loss', ' <=50K'): 21964, ('Reasonable', ' United-States'): 24328, ('Reasonable', ' White'): 22922, (' United-States', ' White'): 24218}
#
#
# C 3 :
#  {('No_Gain', 'Reasonable', ' <=50K'): 18936, ('No_Gain', 'Reasonable', 'No_Loss'): 23141, ('No_Gain', 'Reasonable', ' United-States'): 22184, ('No_Gain', 'Reasonable', ' White'): 20869, ('No_Gain', ' <=50K', 'No_Loss'): 21021, ('No_Gain', ' <=50K', ' United-States'): 19649, ('No_Gain', ' <=50K', ' White'): 18275, ('No_Gain', 'No_Loss', ' White'): 22386, ('Reasonable', ' <=50K', 'No_Loss'): 19151, ('Reasonable', ' <=50K', ' White'): 16586, ('Reasonable', 'No_Loss', ' White'): 21778, ('Reasonable', ' United-States', ' White'): 21369, (' <=50K', 'No_Loss', ' White'): 18489, ('No_Loss', ' United-States', ' White'): 22986}
#
#
# L 3 :
#  {('No_Gain', 'Reasonable', ' <=50K'): 18936, ('No_Gain', 'Reasonable', 'No_Loss'): 23141, ('No_Gain', 'Reasonable', ' United-States'): 22184, ('No_Gain', 'Reasonable', ' White'): 20869, ('No_Gain', ' <=50K', 'No_Loss'): 21021, ('No_Gain', ' <=50K', ' United-States'): 19649, ('No_Gain', ' <=50K', ' White'): 18275, ('No_Gain', 'No_Loss', ' White'): 22386, ('Reasonable', ' <=50K', 'No_Loss'): 19151, ('Reasonable', ' <=50K', ' White'): 16586, ('Reasonable', 'No_Loss', ' White'): 21778, ('Reasonable', ' United-States', ' White'): 21369, (' <=50K', 'No_Loss', ' White'): 18489, ('No_Loss', ' United-States', ' White'): 22986}
#
#
# C 4 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss'): 18329, ('No_Gain', 'Reasonable', ' <=50K', ' United-States'): 17084, ('No_Gain', 'Reasonable', ' <=50K', ' White'): 15873, ('No_Gain', 'Reasonable', 'No_Loss', ' United-States'): 20994, ('No_Gain', 'Reasonable', 'No_Loss', ' White'): 19725, ('No_Gain', 'Reasonable', ' United-States', ' White'): 19417, ('No_Gain', ' <=50K', 'No_Loss', ' United-States'): 19009, ('No_Gain', ' <=50K', 'No_Loss', ' White'): 17670, ('No_Gain', ' <=50K', ' United-States', ' White'): 16922, ('Reasonable', ' <=50K', 'No_Loss', ' United-States'): 17273, ('Reasonable', ' <=50K', 'No_Loss', ' White'): 16056, ('Reasonable', 'No_Loss', ' United-States', ' White'): 20267}
#
#
# L 4 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss'): 18329, ('No_Gain', 'Reasonable', ' <=50K', ' United-States'): 17084, ('No_Gain', 'Reasonable', ' <=50K', ' White'): 15873, ('No_Gain', 'Reasonable', 'No_Loss', ' United-States'): 20994, ('No_Gain', 'Reasonable', 'No_Loss', ' White'): 19725, ('No_Gain', 'Reasonable', ' United-States', ' White'): 19417, ('No_Gain', ' <=50K', 'No_Loss', ' United-States'): 19009, ('No_Gain', ' <=50K', 'No_Loss', ' White'): 17670, ('No_Gain', ' <=50K', ' United-States', ' White'): 16922, ('Reasonable', ' <=50K', 'No_Loss', ' United-States'): 17273, ('Reasonable', ' <=50K', 'No_Loss', ' White'): 16056, ('Reasonable', 'No_Loss', ' United-States', ' White'): 20267}
#
#
# C 5 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' United-States'): 16522, ('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' White'): 15343, ('No_Gain', 'Reasonable', ' <=50K', ' United-States', ' White'): 14648, ('No_Gain', 'Reasonable', 'No_Loss', ' United-States', ' White'): 18315, ('No_Gain', ' <=50K', 'No_Loss', ' United-States', ' White'): 16343, ('Reasonable', ' <=50K', 'No_Loss', ' United-States', ' White'): 14800}
#
#
# L 5 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' United-States'): 16522, ('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' White'): 15343, ('No_Gain', 'Reasonable', ' <=50K', ' United-States', ' White'): 14648, ('No_Gain', 'Reasonable', 'No_Loss', ' United-States', ' White'): 18315, ('No_Gain', ' <=50K', 'No_Loss', ' United-States', ' White'): 16343, ('Reasonable', ' <=50K', 'No_Loss', ' United-States', ' White'): 14800}
#
#
# C 6 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' United-States', ' White'): 14140}
#
#
# L 6 :
#  {('No_Gain', 'Reasonable', ' <=50K', 'No_Loss', ' United-States', ' White'): 14140}
#
#
# C 7 :
#  {}
#
#
# L 7 :
#  {}
#
# Total execution time =  220.52955222129822
