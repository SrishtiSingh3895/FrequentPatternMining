# %% [markdown]
# ## Apriori Frequent Pattern Mining improved using Transaction Reduction

# %%
import pandas as pd
import numpy as np
from itertools import combinations
import time

# %%
# Reading data file
adult = pd.read_excel('adult.xlsx')
adult.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Edunum              Marital  \
# 0   39          State-gov   77516   Bachelors      13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors      13   Married-civ-spouse
# 2   38            Private  215646     HS-grad       9             Divorced
# 3   53            Private  234721        11th       7   Married-civ-spouse
# 4   28            Private  338409   Bachelors      13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Gain  Loss  \
# 0        Adm-clerical   Not-in-family   White     Male  2174     0
# 1     Exec-managerial         Husband   White     Male     0     0
# 2   Handlers-cleaners   Not-in-family   White     Male     0     0
# 3   Handlers-cleaners         Husband   Black     Male     0     0
# 4      Prof-specialty            Wife   Black   Female     0     0
#
#    Hoursperweek         Country  Income
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K
# 2            40   United-States   <=50K
# 3            40   United-States   <=50K
# 4            40            Cuba   <=50K

# %%
# Removing irrelevant columns
adult.drop(['fnlwgt', 'Edunum'], axis = 1, inplace = True)
adult.head()
# Out:
#    Age          Workclass   Education              Marital  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Gain  Loss  \
# 0        Adm-clerical   Not-in-family   White     Male  2174     0
# 1     Exec-managerial         Husband   White     Male     0     0
# 2   Handlers-cleaners   Not-in-family   White     Male     0     0
# 3   Handlers-cleaners         Husband   Black     Male     0     0
# 4      Prof-specialty            Wife   Black   Female     0     0
#
#    Hoursperweek         Country  Income
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K
# 2            40   United-States   <=50K
# 3            40   United-States   <=50K
# 4            40            Cuba   <=50K

# %%
# Size of original data
adult.shape
# Out:
# (32561, 13)

# %%
# Removing missing values from data
adult.replace(' ?', np.NaN, inplace = True)
adult.dropna(axis = 0, inplace = True)

# Size of data after removing missing values
adult.shape
adult.head()
# Out:
#    Age          Workclass   Education              Marital  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Gain  Loss  \
# 0        Adm-clerical   Not-in-family   White     Male  2174     0
# 1     Exec-managerial         Husband   White     Male     0     0
# 2   Handlers-cleaners   Not-in-family   White     Male     0     0
# 3   Handlers-cleaners         Husband   Black     Male     0     0
# 4      Prof-specialty            Wife   Black   Female     0     0
#
#    Hoursperweek         Country  Income
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K
# 2            40   United-States   <=50K
# 3            40   United-States   <=50K
# 4            40            Cuba   <=50K

# %%
# Size of data after removing missing values and resetting index
adult.shape
adult.reset_index(drop = True, inplace = True)
adult.tail()
# Out:
#        Age      Workclass    Education              Marital  \
# 30157   27        Private   Assoc-acdm   Married-civ-spouse
# 30158   40        Private      HS-grad   Married-civ-spouse
# 30159   58        Private      HS-grad              Widowed
# 30160   22        Private      HS-grad        Never-married
# 30161   52   Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation Relationship    Race      Sex   Gain  Loss  \
# 30157        Tech-support         Wife   White   Female      0     0
# 30158   Machine-op-inspct      Husband   White     Male      0     0
# 30159        Adm-clerical    Unmarried   White   Female      0     0
# 30160        Adm-clerical    Own-child   White     Male      0     0
# 30161     Exec-managerial         Wife   White   Female  15024     0
#
#        Hoursperweek         Country  Income
# 30157            38   United-States   <=50K
# 30158            40   United-States    >50K
# 30159            40   United-States   <=50K
# 30160            20   United-States   <=50K
# 30161            40   United-States    >50K

# %%
# Converting numeric data to categorical data
adult['Age'] = pd.cut(adult['Age'], [0, 25, 40, np.inf], labels=["young", "middle_aged", "old"])
adult['Gain'] = pd.cut(adult['Gain'], [-1, 1, np.inf], labels=["No_Gain", "Gain"])
adult['Loss'] = pd.cut(adult['Loss'], [-1, 1, np.inf], labels=["No_Loss", "Loss"])
adult['Hoursperweek'] = pd.cut(adult['Hoursperweek'], [-1, 5, 20, 60, np.inf], labels=["Less", "Medium", "Reasonable", "High"])
adult.head()
# Out:
#            Age          Workclass   Education              Marital  \
# 0  middle_aged          State-gov   Bachelors        Never-married
# 1          old   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2  middle_aged            Private     HS-grad             Divorced
# 3          old            Private        11th   Married-civ-spouse
# 4  middle_aged            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex     Gain     Loss  \
# 0        Adm-clerical   Not-in-family   White     Male     Gain  No_Loss
# 1     Exec-managerial         Husband   White     Male  No_Gain  No_Loss
# 2   Handlers-cleaners   Not-in-family   White     Male  No_Gain  No_Loss
# 3   Handlers-cleaners         Husband   Black     Male  No_Gain  No_Loss
# 4      Prof-specialty            Wife   Black   Female  No_Gain  No_Loss
#
#   Hoursperweek         Country  Income
# 0   Reasonable   United-States   <=50K
# 1       Medium   United-States   <=50K
# 2   Reasonable   United-States   <=50K
# 3   Reasonable   United-States   <=50K
# 4   Reasonable            Cuba   <=50K

# %%
# Generating Candidate 1
def C1(data):
    candidates = {} # empty dictionary to store each item as key and its count as value
    for i in data.index:
        for j in data.loc[i]:
            if (j in candidates): 
                candidates[j] += 1
            else: 
                candidates[j] = 1
    print("\nC1: \n", candidates)
    return candidates

# %%
# Generating L1
def L1(c, support):
    l1 = {} # dictionary to store all the items having support more than or equal to minimum support
    l1 = dict((k,v) for k, v in c.items() if v >= support)
    print("\n\nL1: \n", l1)
    return l1

# %%
# Function to check if candidate itemset contains infrequent subset
def has_infrequent_subset(candidate, freq, prevL):
    for i in list(combinations(candidate,freq-1)):
        if i not in prevL:
            return True
        return False

# %%
# Generating Candidate k
def Ck(k, prevL, df):
    
    # Join
    if k == 2:
        c = list()
        for key,v in prevL.items():
            if key not in c:
                c.append(key)
            
    # When k is greater than 2, L (k-1) contains list of tuples
    if k > 2:
        c = list()
        for key,v in prevL.items():
            for item in key:
                if item not in c:
                    c.append(item)
                    
    candidates = {} # To store all the candidate items along with its count
    cand = list(combinations(c, k))
    
    # Prune
    for cd in cand:
        if (has_infrequent_subset(cd, k, prevL) == True):
            cand.remove(cd)
    
    count = {}
    for i in cand:
        candidates[i] = 0
    for i in range(len(df)):
        count[i] = 0
        
    for ind in df.index:
        for i in candidates:
            if set(i).issubset(df.loc[ind]):
                candidates[i] +=1
                count[ind] += 1
                
    print("\n\nC", k, ":\n", candidates)
    
    if candidates != {}:
        for ind in df.index:   
            if (count[ind] == 0):
                df.loc[ind] = np.NaN
            
        df.dropna(axis = 0, inplace = True)        
        adult.reset_index(drop = True, inplace = True)
    
    print("\nShape after reduction:")
    print(df.shape)
    
    return candidates

# %%
# Generating Lk
def Lk(k, ck, support, df):
    lk = {}
    count = {}
    lk = dict((key,v) for key, v in ck.items() if v >= support)

    print("\n\nL", k, ":\n", lk)
    return lk

# %%
# Function for Apriori Algorithm
def apriori(data, support):
    t1 = time.time()
    s = int((support/100)*len(data))
    print("Min sup = ", s)
    lk = {}
    k = 2
    candidateK = {}
    candidateK = C1(data)
    lk = L1(candidateK, s)
    while lk != {}:
        candidateK = Ck(k, lk, data)
        lk = Lk(k, candidateK, s, data)
        k += 1
    t2 = time.time()
    exec_time = t2 - t1
    print("\nExecution time = ", exec_time)
    return

# %%
apriori(adult, 50)
# Out:
# Min sup =  15080
#
# C1:
#  {'middle_aged': 12091, ' State-gov': 1279, ' Bachelors': 5044, ' Never-married': 9726, ' Adm-clerical': 3721, ' Not-in-family': 7725, ' White': 25933, ' Male': 20380, 'Gain': 2538, 'No_Loss': 28734, 'Reasonable': 26721, ' United-States': 27504, ' <=50K': 22654, 'old': 12401, ' Self-emp-not-inc': 2498, ' Married-civ-spouse': 14064, ' Exec-managerial': 3990, ' Husband': 12463, 'No_Gain': 27622, 'Medium': 2277, ' Private': 22286, ' HS-grad': 9839, ' Divorced': 4213, ' Handlers-cleaners': 1350, ' 11th': 1048, ' Black': 2817, ' Prof-specialty': 4038, ' Wife': 1405, ' Female': 9780, ' Cuba': 92, ' Masters': 1627, ' 9th': 455, ' Married-spouse-absent': 370, ' Other-service': 3212, ' Jamaica': 80, ' >50K': 7506, ' Some-college': 6677, 'High': 1051, ' Asian-Pac-Islander': 893, ' India': 100, 'young': 5668, ' Own-child': 4466, ' Assoc-acdm': 1008, ' Sales': 3584, ' 7th-8th': 557, ' Transport-moving': 1572, ' Amer-Indian-Eskimo': 286, ' Mexico': 610, ' Farming-fishing': 989, ' Machine-op-inspct': 1966, ' Unmarried': 3212, ' Doctorate': 375, ' Separated': 939, ' Federal-gov': 942, 'Loss': 1426, ' Tech-support': 912, ' Local-gov': 2067, ' Craft-repair': 4030, ' Protective-serv': 644, ' Puerto-Rico': 109, ' Married-AF-spouse': 21, ' Assoc-voc': 1307, ' Other': 231, ' Prof-school': 542, ' Honduras': 12, ' Self-emp-inc': 1074, ' 5th-6th': 288, ' Other-relative': 889, ' England': 86, ' Canada': 107, ' Germany': 128, ' Iran': 42, ' Widowed': 827, ' Philippines': 187, 'Less': 111, ' Poland': 56, ' 10th': 820, ' Preschool': 45, ' Columbia': 56, ' Cambodia': 18, ' Thailand': 17, ' Ecuador': 27, ' Laos': 17, ' Taiwan': 42, ' Haiti': 42, ' Portugal': 34, ' 12th': 377, ' 1st-4th': 151, ' Dominican-Republic': 67, ' Armed-Forces': 9, ' El-Salvador': 100, ' France': 27, ' Priv-house-serv': 143, ' Guatemala': 63, ' Italy': 68, ' China': 68, ' South': 70, ' Japan': 59, ' Yugoslavia': 16, ' Peru': 30, ' Outlying-US(Guam-USVI-etc)': 14, ' Scotland': 11, ' Trinadad&Tobago': 18, ' Greece': 29, ' Without-pay': 14, ' Nicaragua': 33, ' Vietnam': 64, ' Hong': 19, ' Ireland': 24, ' Hungary': 13, ' Holand-Netherlands': 1}
#
#
# L1:
#  {' White': 25933, ' Male': 20380, 'No_Loss': 28734, 'Reasonable': 26721, ' United-States': 27504, ' <=50K': 22654, 'No_Gain': 27622, ' Private': 22286}
#
#
# C 2 :
#  {(' White', 'No_Loss'): 24651, (' White', ' United-States'): 24218, (' White', 'No_Gain'): 23668, (' Male', 'No_Loss'): 19290, (' Male', ' United-States'): 18572, (' Male', 'No_Gain'): 18403, ('No_Loss', 'Reasonable'): 25444, ('No_Loss', ' <=50K'): 21964, ('No_Loss', ' Private'): 21326, ('Reasonable', ' <=50K'): 19758, ('Reasonable', ' Private'): 19931, (' United-States', 'No_Gain'): 25145, (' <=50K', 'No_Gain'): 21711, ('No_Gain', ' Private'): 20583}
#
# Shape after reduction:
# (30160, 13)
#
#
# L 2 :
#  {(' White', 'No_Loss'): 24651, (' White', ' United-States'): 24218, (' White', 'No_Gain'): 23668, (' Male', 'No_Loss'): 19290, (' Male', ' United-States'): 18572, (' Male', 'No_Gain'): 18403, ('No_Loss', 'Reasonable'): 25444, ('No_Loss', ' <=50K'): 21964, ('No_Loss', ' Private'): 21326, ('Reasonable', ' <=50K'): 19758, ('Reasonable', ' Private'): 19931, (' United-States', 'No_Gain'): 25145, (' <=50K', 'No_Gain'): 21711, ('No_Gain', ' Private'): 20583}
#
#
# C 3 :
#  {(' White', 'No_Loss', ' United-States'): 22986, (' White', 'No_Loss', 'No_Gain'): 22386, (' White', 'No_Loss', ' Male'): 17049, (' White', 'No_Loss', 'Reasonable'): 21778, (' White', 'No_Loss', ' <=50K'): 18489, (' White', 'No_Loss', ' Private'): 18273, (' White', ' United-States', 'No_Gain'): 22068, (' White', ' United-States', ' Male'): 16848, (' White', ' United-States', 'Reasonable'): 21369, (' White', ' United-States', ' <=50K'): 17679, (' White', ' United-States', ' Private'): 17728, (' White', 'No_Gain', ' Male'): 16242, (' White', 'No_Gain', 'Reasonable'): 20869, (' White', 'No_Gain', ' <=50K'): 18275, (' White', 'No_Gain', ' Private'): 17619, (' White', ' Male', ' <=50K'): 12170, (' White', 'Reasonable', ' <=50K'): 16586, (' White', ' <=50K', ' Private'): 14670, ('No_Loss', ' United-States', ' Male'): 17562, ('No_Loss', ' United-States', ' <=50K'): 19869, ('No_Loss', 'No_Gain', ' Male'): 17313, ('No_Loss', 'No_Gain', ' <=50K'): 21021, ('No_Loss', ' Male', 'Reasonable'): 17377, ('No_Loss', ' Male', ' Private'): 13925, ('No_Loss', 'Reasonable', ' <=50K'): 19151, ('No_Loss', 'Reasonable', ' Private'): 19060, ('No_Loss', ' <=50K', ' Private'): 16914, (' United-States', 'No_Gain', ' Male'): 16738, (' United-States', 'No_Gain', 'Reasonable'): 22184, (' United-States', 'No_Gain', ' <=50K'): 19649, (' United-States', 'No_Gain', ' Private'): 18558, (' United-States', ' Male', ' <=50K'): 12601, (' United-States', 'Reasonable', ' <=50K'): 17835, (' United-States', ' <=50K', ' Private'): 15594, ('No_Gain', ' Male', ' <=50K'): 13347, ('No_Gain', 'Reasonable', ' <=50K'): 18936, ('No_Gain', ' <=50K', ' Private'): 16726, (' Male', 'Reasonable', ' Private'): 13397, ('Reasonable', ' <=50K', ' Private'): 15336}
#
# Shape after reduction:
# (30127, 13)
#
#
# L 3 :
#  {(' White', 'No_Loss', ' United-States'): 22986, (' White', 'No_Loss', 'No_Gain'): 22386, (' White', 'No_Loss', ' Male'): 17049, (' White', 'No_Loss', 'Reasonable'): 21778, (' White', 'No_Loss', ' <=50K'): 18489, (' White', 'No_Loss', ' Private'): 18273, (' White', ' United-States', 'No_Gain'): 22068, (' White', ' United-States', ' Male'): 16848, (' White', ' United-States', 'Reasonable'): 21369, (' White', ' United-States', ' <=50K'): 17679, (' White', ' United-States', ' Private'): 17728, (' White', 'No_Gain', ' Male'): 16242, (' White', 'No_Gain', 'Reasonable'): 20869, (' White', 'No_Gain', ' <=50K'): 18275, (' White', 'No_Gain', ' Private'): 17619, (' White', 'Reasonable', ' <=50K'): 16586, ('No_Loss', ' United-States', ' Male'): 17562, ('No_Loss', ' United-States', ' <=50K'): 19869, ('No_Loss', 'No_Gain', ' Male'): 17313, ('No_Loss', 'No_Gain', ' <=50K'): 21021, ('No_Loss', ' Male', 'Reasonable'): 17377, ('No_Loss', 'Reasonable', ' <=50K'): 19151, ('No_Loss', 'Reasonable', ' Private'): 19060, ('No_Loss', ' <=50K', ' Private'): 16914, (' United-States', 'No_Gain', ' Male'): 16738, (' United-States', 'No_Gain', 'Reasonable'): 22184, (' United-States', 'No_Gain', ' <=50K'): 19649, (' United-States', 'No_Gain', ' Private'): 18558, (' United-States', 'Reasonable', ' <=50K'): 17835, (' United-States', ' <=50K', ' Private'): 15594, ('No_Gain', 'Reasonable', ' <=50K'): 18936, ('No_Gain', ' <=50K', ' Private'): 16726, ('Reasonable', ' <=50K', ' Private'): 15336}
#
#
# C 4 :
#  {(' White', 'No_Loss', ' United-States', 'No_Gain'): 20836, (' White', 'No_Loss', ' United-States', ' Male'): 15898, (' White', 'No_Loss', ' United-States', 'Reasonable'): 20267, (' White', 'No_Loss', ' United-States', ' <=50K'): 17100, (' White', 'No_Loss', ' United-States', ' Private'): 16895, (' White', 'No_Loss', 'No_Gain', ' Male'): 15253, (' White', 'No_Loss', 'No_Gain', 'Reasonable'): 19725, (' White', 'No_Loss', 'No_Gain', ' <=50K'): 17670, (' White', 'No_Loss', 'No_Gain', ' Private'): 16755, (' White', 'No_Loss', ' Male', 'Reasonable'): 15352, (' White', 'No_Loss', ' Male', ' <=50K'): 11769, (' White', 'No_Loss', ' Male', ' Private'): 12270, (' White', 'No_Loss', 'Reasonable', ' <=50K'): 16056, (' White', 'No_Loss', 'Reasonable', ' Private'): 16314, (' White', 'No_Loss', ' <=50K', ' Private'): 14233, (' White', ' United-States', 'No_Gain', ' Male'): 15140, (' White', ' United-States', 'No_Gain', 'Reasonable'): 19417, (' White', ' United-States', 'No_Gain', ' <=50K'): 16922, (' White', ' United-States', 'No_Gain', ' Private'): 16292, (' White', ' United-States', ' Male', 'Reasonable'): 15155, (' White', ' United-States', ' Male', ' <=50K'): 11229, (' White', ' United-States', ' Male', ' Private'): 11956, (' White', ' United-States', 'Reasonable', ' <=50K'): 15308, (' White', ' United-States', 'Reasonable', ' Private'): 15803, (' White', ' United-States', ' <=50K', ' Private'): 13452, (' White', 'No_Gain', ' Male', 'Reasonable'): 14612, (' White', 'No_Gain', ' Male', ' <=50K'): 11598, (' White', 'No_Gain', ' Male', ' Private'): 11730, (' White', 'No_Gain', 'Reasonable', ' <=50K'): 15873, (' White', 'No_Gain', 'Reasonable', ' Private'): 15701, (' White', 'No_Gain', ' <=50K', ' Private'): 14071, (' White', ' Male', 'Reasonable', ' Private'): 11827, (' White', 'Reasonable', ' <=50K', ' Private'): 12888, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable'): 20994, ('No_Loss', ' United-States', 'No_Gain', ' Private'): 17660, ('No_Loss', ' United-States', ' Male', 'Reasonable'): 15806, ('No_Loss', ' United-States', ' Male', ' <=50K'): 12187, ('No_Loss', ' United-States', ' Male', ' Private'): 12538, ('No_Loss', ' United-States', 'Reasonable', ' Private'): 17144, ('No_Loss', ' United-States', ' <=50K', ' Private'): 15132, ('No_Loss', 'No_Gain', ' Male', 'Reasonable'): 15575, ('No_Loss', 'No_Gain', ' Male', ' <=50K'): 12898, ('No_Loss', 'No_Gain', ' Male', ' Private'): 12609, ('No_Loss', 'No_Gain', 'Reasonable', ' Private'): 17496, ('No_Loss', 'No_Gain', ' <=50K', ' Private'): 16230, ('No_Loss', ' Male', 'Reasonable', ' <=50K'): 12012, ('No_Loss', ' Male', 'Reasonable', ' Private'): 12732, ('No_Loss', 'Reasonable', ' <=50K', ' Private'): 14891, (' United-States', 'No_Gain', ' Male', 'Reasonable'): 15053, (' United-States', 'No_Gain', ' Male', ' <=50K'): 12023, (' United-States', 'No_Gain', ' Male', ' Private'): 11991, (' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 17084, (' United-States', 'No_Gain', 'Reasonable', ' Private'): 16510, (' United-States', 'No_Gain', ' <=50K', ' Private'): 14976, (' United-States', ' Male', 'Reasonable', ' Private'): 12070, (' United-States', 'Reasonable', ' <=50K', ' Private'): 13678, ('No_Gain', ' Male', 'Reasonable', ' Private'): 12174, ('No_Gain', 'Reasonable', ' <=50K', ' Private'): 14733}
# Shape after reduction:
# (29967, 13)
#
#
# L 4 :
#  {(' White', 'No_Loss', ' United-States', 'No_Gain'): 20836, (' White', 'No_Loss', ' United-States', ' Male'): 15898, (' White', 'No_Loss', ' United-States', 'Reasonable'): 20267, (' White', 'No_Loss', ' United-States', ' <=50K'): 17100, (' White', 'No_Loss', ' United-States', ' Private'): 16895, (' White', 'No_Loss', 'No_Gain', ' Male'): 15253, (' White', 'No_Loss', 'No_Gain', 'Reasonable'): 19725, (' White', 'No_Loss', 'No_Gain', ' <=50K'): 17670, (' White', 'No_Loss', 'No_Gain', ' Private'): 16755, (' White', 'No_Loss', ' Male', 'Reasonable'): 15352, (' White', 'No_Loss', 'Reasonable', ' <=50K'): 16056, (' White', 'No_Loss', 'Reasonable', ' Private'): 16314, (' White', ' United-States', 'No_Gain', ' Male'): 15140, (' White', ' United-States', 'No_Gain', 'Reasonable'): 19417, (' White', ' United-States', 'No_Gain', ' <=50K'): 16922, (' White', ' United-States', 'No_Gain', ' Private'): 16292, (' White', ' United-States', ' Male', 'Reasonable'): 15155, (' White', ' United-States', 'Reasonable', ' <=50K'): 15308, (' White', ' United-States', 'Reasonable', ' Private'): 15803, (' White', 'No_Gain', 'Reasonable', ' <=50K'): 15873, (' White', 'No_Gain', 'Reasonable', ' Private'): 15701, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable'): 20994, ('No_Loss', ' United-States', 'No_Gain', ' Private'): 17660, ('No_Loss', ' United-States', ' Male', 'Reasonable'): 15806, ('No_Loss', ' United-States', 'Reasonable', ' Private'): 17144, ('No_Loss', ' United-States', ' <=50K', ' Private'): 15132, ('No_Loss', 'No_Gain', ' Male', 'Reasonable'): 15575, ('No_Loss', 'No_Gain', 'Reasonable', ' Private'): 17496, ('No_Loss', 'No_Gain', ' <=50K', ' Private'): 16230, (' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 17084, (' United-States', 'No_Gain', 'Reasonable', ' Private'): 16510}
#
#
# C 5 :
#  {(' White', 'No_Loss', ' United-States', 'No_Gain', ' Male'): 14190, (' White', 'No_Loss', ' United-States', 'No_Gain', 'Reasonable'): 18315, (' White', 'No_Loss', ' United-States', 'No_Gain', ' <=50K'): 16343, (' White', 'No_Loss', ' United-States', 'No_Gain', ' Private'): 15459, (' White', 'No_Loss', ' United-States', ' Male', 'Reasonable'): 14291, (' White', 'No_Loss', ' United-States', ' Male', ' <=50K'): 10844, (' White', 'No_Loss', ' United-States', ' Male', ' Private'): 11325, (' White', 'No_Loss', ' United-States', 'Reasonable', ' <=50K'): 14800, (' White', 'No_Loss', ' United-States', 'Reasonable', ' Private'): 15049, (' White', 'No_Loss', ' United-States', ' <=50K', ' Private'): 13033, (' White', 'No_Loss', 'No_Gain', ' Male', 'Reasonable'): 13715, (' White', 'No_Loss', 'No_Gain', ' Male', ' <=50K'): 11197, (' White', 'No_Loss', 'No_Gain', ' Male', ' Private'): 11076, (' White', 'No_Loss', 'No_Gain', 'Reasonable', ' <=50K'): 15343, (' White', 'No_Loss', 'No_Gain', 'Reasonable', ' Private'): 14920, (' White', 'No_Loss', 'No_Gain', ' <=50K', ' Private'): 13634, (' White', 'No_Loss', ' Male', 'Reasonable', ' <=50K'): 10428, (' White', 'No_Loss', ' Male', 'Reasonable', ' Private'): 11225, (' White', 'No_Loss', 'Reasonable', ' <=50K', ' Private'): 12498, (' White', ' United-States', 'No_Gain', ' Male', 'Reasonable'): 13597, (' White', ' United-States', 'No_Gain', ' Male', ' <=50K'): 10699, (' White', ' United-States', 'No_Gain', ' Male', ' Private'): 10824, (' White', ' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 14648, (' White', ' United-States', 'No_Gain', 'Reasonable', ' Private'): 14483, (' White', ' United-States', 'No_Gain', ' <=50K', ' Private'): 12903, (' White', ' United-States', ' Male', 'Reasonable', ' <=50K'): 9922, (' White', ' United-States', ' Male', 'Reasonable', ' Private'): 10929, (' White', ' United-States', 'Reasonable', ' <=50K', ' Private'): 11775, (' White', 'No_Gain', ' Male', 'Reasonable', ' Private'): 10717, (' White', 'No_Gain', 'Reasonable', ' <=50K', ' Private'): 12358, ('No_Loss', ' United-States', 'No_Gain', ' Male', 'Reasonable'): 14133, ('No_Loss', ' United-States', 'No_Gain', ' Male', ' Private'): 11320, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 16522, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' Private'): 15696, ('No_Loss', ' United-States', ' Male', 'Reasonable', ' <=50K'): 10792, ('No_Loss', ' United-States', ' Male', 'Reasonable', ' Private'): 11449, ('No_Loss', ' United-States', 'Reasonable', ' <=50K', ' Private'): 13265, ('No_Loss', 'No_Gain', ' Male', 'Reasonable', ' <=50K'): 11450, ('No_Loss', 'No_Gain', ' Male', 'Reasonable', ' Private'): 11509, ('No_Loss', 'No_Gain', 'Reasonable', ' <=50K', ' Private'): 14288, (' United-States', 'No_Gain', ' Male', 'Reasonable', ' <=50K'): 10653, (' United-States', 'No_Gain', ' Male', ' <=50K', ' Private'): 8913, (' United-States', 'No_Gain', 'Reasonable', ' <=50K', ' Private'): 13133, ('No_Gain', ' Male', 'Reasonable', ' <=50K', ' Private'): 9049}
#
# Shape after reduction:
# (29181, 13)
#
#
# L 5 :
#  {(' White', 'No_Loss', ' United-States', 'No_Gain', 'Reasonable'): 18315, (' White', 'No_Loss', ' United-States', 'No_Gain', ' <=50K'): 16343, (' White', 'No_Loss', ' United-States', 'No_Gain', ' Private'): 15459, (' White', 'No_Loss', 'No_Gain', 'Reasonable', ' <=50K'): 15343, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 16522, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' Private'): 15696}
#
#
# C 6 :
#  {(' White', 'No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' <=50K'): 14140, (' White', 'No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' Private'): 13729, (' White', 'No_Loss', ' United-States', 'No_Gain', ' <=50K', ' Private'): 12484, (' White', 'No_Loss', 'No_Gain', 'Reasonable', ' <=50K', ' Private'): 11968, ('No_Loss', ' United-States', 'No_Gain', 'Reasonable', ' <=50K', ' Private'): 12720}
#
# Shape after reduction:
# (21381, 13)
#
#
# L 6 :
#  {}
#
# Execution time =  949.907653093338
